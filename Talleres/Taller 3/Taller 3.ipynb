# %% [markdown]
# ![Grafos](https://raw.githubusercontent.com/jspenaq/Algoritmos/master/Talleres/Taller%203/Grafos%20Taller%203.PNG?token=Aiu9bEi4G__sO_ZBWrDmYxAsvRfBSM8zks5bH--OwA%3D%3D "Grafos")
#
# ### 1) Para los 3 grafos, calcule (por inspeccion) la longitud los caminos mas cortos desde el nodo 0 hacia el resto de nodos.
#
# a)
# [0,1]= 5
# [0,2]= 3
# [0,3]= 6
# [0,4]= 8
#
# b)
# [0,1]= 5
# [0,2]= 3
# [0,3]= 6
# [0,4]= 9
#
# c)
# [0,1]= 2
# [0,2]= 1
# [0,3]= 5
# [0,4]= 7
#
# ### 2) Para el grafo b, puede encontrar un camino desde 0 a 1 de costo 0? Explique
#
# Si se puede porque el loop [2,1,3] tiene costo negativo, si se realizan varios loops se puede reducir el costo
# hasta llegar a 0
#
# ### 3) El siguiente c ́odigo (Cormen et al, 2009) implementa el algoritmo de Bellman-Ford para encontrar caminos mas cortos desde una sola fuente:
#
# ### Grafo a:

# %%
"""
https://github.com/prakhar1989/Algorithms/blob/master/dp/bellman_ford.py
http://www.programming-algorithms.net/article/47389/Bellman-Ford-algorithm
"""
G = {
    '0' : {'1': 9, '2': 3},
    '1' : {'3':1},
    '2': {'1': 2, '3': 6, '4': 6 },
    '3': {'2': 4, '4': 2},
    '4': {},
    

}

inf = float("inf")

dist = {}
predecessor = {}

def initialize_single_source(graph, start):
    for v in graph:
        dist[v] = inf
        predecessor[v] = None
    dist[start] = 0

def relax(graph, u, v):
    if dist[v] > dist[u] + graph[u][v]:
        dist[v] = dist[u] + graph[u][v]
        predecessor[v] = u

def bellman_ford(graph, start):
    initialize_single_source(graph, start)
    n = len(graph)
    edges = [(u, v) for u in graph for v in graph[u].keys()]

    for i in range(n-1):
        for (u,v) in edges:
            relax(graph, u, v)
    for (u,v) in edges:
        if dist[v] > dist[u] + graph[u][v]:
            return False # there exists a negative cycle
    return True

def get_distances(graph, start):
    if bellman_ford(graph, start):
        return dist
    return "Graph contains a negative cycle"
print(get_distances(G, '0'))
print(get_distances(G, '1'))
print(get_distances(G, '2'))
print(get_distances(G, '3'))
print(get_distances(G, '4'))
# Out:
# {'0': 0, '1': 5, '2': 3, '3': 6, '4': 8}
# {'0': inf, '1': 0, '2': 5, '3': 1, '4': 3}
# {'0': inf, '1': 2, '2': 0, '3': 3, '4': 5}
# {'0': inf, '1': 6, '2': 4, '3': 0, '4': 2}
# {'0': inf, '1': inf, '2': inf, '3': inf, '4': 0}

# %% [markdown]
# ### Grafo b:

# %%
"""
https://github.com/prakhar1989/Algorithms/blob/master/dp/bellman_ford.py
http://www.programming-algorithms.net/article/47389/Bellman-Ford-algorithm
"""
G = {
    '0' : {'1': 9, '2': 3},
    '1' : {'3':1},
    '2': {'1': 2, '3': 6, '4': 6 },
    '3': {'2': -4, '4': 2},
    '4': {},
    

}

inf = float("inf")

dist = {}
predecessor = {}

def initialize_single_source(graph, start):
    for v in graph:
        dist[v] = inf
        predecessor[v] = None
    dist[start] = 0

def relax(graph, u, v):
    if dist[v] > dist[u] + graph[u][v]:
        dist[v] = dist[u] + graph[u][v]
        predecessor[v] = u

def bellman_ford(graph, start):
    initialize_single_source(graph, start)
    n = len(graph)
    edges = [(u, v) for u in graph for v in graph[u].keys()]

    for i in range(n-1):
        for (u,v) in edges:
            relax(graph, u, v)
    for (u,v) in edges:
        if dist[v] > dist[u] + graph[u][v]:
            return False # there exists a negative cycle
    return True

def get_distances(graph, start):
    if bellman_ford(graph, start):
        return dist
    return "Graph contains a negative cycle"
print(get_distances(G, '0'))
print(get_distances(G, '1'))
print(get_distances(G, '2'))
print(get_distances(G, '3'))
print(get_distances(G, '4'))
# Out:
# Graph contains a negative cycle
# Graph contains a negative cycle
# Graph contains a negative cycle
# Graph contains a negative cycle
# {'0': inf, '1': inf, '2': inf, '3': inf, '4': 0}

# %% [markdown]
# ### Grafo c:

# %%
"""
https://github.com/prakhar1989/Algorithms/blob/master/dp/bellman_ford.py
http://www.programming-algorithms.net/article/47389/Bellman-Ford-algorithm
"""
G = {
    '0' : {'1': 2, '2': 8},
    '1' : {'3':3},
    '2': {'1': 2, '3': 6, '4': 6 },
    '3': {'2': -4, '4': 2},
    '4': {},
    

}

inf = float("inf")

dist = {}
predecessor = {}

def initialize_single_source(graph, start):
    for v in graph:
        dist[v] = inf
        predecessor[v] = None
    dist[start] = 0

def relax(graph, u, v):
    if dist[v] > dist[u] + graph[u][v]:
        dist[v] = dist[u] + graph[u][v]
        predecessor[v] = u

def bellman_ford(graph, start):
    initialize_single_source(graph, start)
    n = len(graph)
    edges = [(u, v) for u in graph for v in graph[u].keys()]

    for i in range(n-1):
        for (u,v) in edges:
            relax(graph, u, v)
            
    for (u,v) in edges:
        if dist[v] > dist[u] + graph[u][v]:
            return False # there exists a negative cycle
    return True

def get_distances(graph, start):
    if bellman_ford(graph, start):
        return dist
    return "Graph contains a negative cycle"
print(get_distances(G, '0'))
print(get_distances(G, '1'))
print(get_distances(G, '2'))
print(get_distances(G, '3'))
print(get_distances(G, '4'))
# Out:
# {'0': 0, '1': 2, '2': 1, '3': 5, '4': 7}
# {'0': inf, '1': 0, '2': -1, '3': 3, '4': 5}
# {'0': inf, '1': 2, '2': 0, '3': 5, '4': 6}
# {'0': inf, '1': -2, '2': -4, '3': 0, '4': 2}
# {'0': inf, '1': inf, '2': inf, '3': inf, '4': 0}

# %% [markdown]
# ### 4) ¿Que paso con el grafo b? Explique.
#
# Como tiene ciclos negativos no puede retornar la menor distancia, lo cual representaria una distancia en la practica de - Infinito
#
# ### 5) En cada caso, ¿cu ́antas llamadas se hicieron a la funcion Relax? ¿puede hacerse de manera mas eficiente?
#
# 32 veces, y ademas se puede hacer mas eficientemente (Se explica en el siguiente punto)
#
# ### 6) Para los grafos a y c, muestre una secuencia de llamadas a Relax que le permita calcular los caminos mas cortos de una manera m ́as eficiente.
#
# Se puede mejorar la cantidad de veces que se hace relax si se paran las iteraciones de cada nodo cuando no se hacen cambios en la tabla tras una iteracón
